# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import mltools.pca as pca
import mltools.location_scatter as loc
import mltools.plots as plots
import mltools.aggfuncs as aggfuncs
import mltools.funcs as funcs
from mltools.scores import modified_zscore

# %%
df = pd.read_csv("data/kelly1984.csv", sep=',')
df
# Out:
#     heelstick  catheter
# 0        23.0      25.2
# 1        33.2      26.0
# 2        16.6      16.3
# 3        26.3      27.2
# 4        20.0      23.2
# 5        20.0      18.1
# 6        20.6      22.2
# 7        18.9      17.2
# 8        17.8      18.8
# 9        20.0      16.4
# 10       26.4      24.8
# 11       21.8      26.8
# 12       14.9      15.4
# 13       17.4      14.9
# 14       20.0      18.1
# 15       13.2      16.3
# 16       28.4      31.3
# 17       25.9      31.2
# 18       18.9      18.0
# 19       13.8      15.6

# %%
X0 = df.values
N = len(X0)
W = X0[:,0].max() - X0[:,0].min()
H = X0[:,1].max() - X0[:,1].min()
W /= 4
H /= 4

# %%
alpha = (N-3)/N
print(alpha)
# Out:
# 0.85

# %%
aa = 16/9
plt.figure(figsize=(W,H))
plt.scatter(X0[:,0], X0[:,1], c='w', s=25, edgecolors='k')
plt.show()

# %%
c0 = pca.location(X0)
print(c0)
plt.plot(sorted(pca.distance_center(X0, c0)), marker='s', markersize=4)
plt.show()
# Out:
# [20.855 21.150]

# %%
# alpha = (N-5)/N
wma = af.averaging_function("WM", rhofunc=funcs.Quantile_Sqrt(alpha, 0.001))
c = pca.robust_location(X0, wma)
print(c)
plt.plot(sorted(pca.distance_center(X0, c)), marker='s', markersize=4)
plt.show()
# Out:
# [20.425 20.805]

# %%
X1 = X0 - c
X1_0 = X0 - c0

# %%
a1_0, L1_0 = pca.find_pc(X1_0, tol=1.0e-9, verbose=1)
print(L1_0, a1_0)
plt.plot(sorted(pca.distance_line(X1_0, a1_0)), marker='s', markersize=4)
plt.show()
# Out:
# K: 7 L: 48.01627447052377 PC: [0.683 0.731]
# 48.01627447052377 [0.683 0.731]

# %%
# alpha = (N-3)/N
wma = af.averaging_function("WM", rhofunc=funcs.Quantile_Sqrt(alpha, 0.001))
a1, L1 = pca.find_robust_pc(X1, wma, tol=1.0e-9)
print(L1, a1)
plt.plot(sorted(pca.distance_line(X1, a1)), marker='s', markersize=4)
plt.show()
# Out:
# 41.25927927674594 [0.571 0.821]

# %%
plt.scatter(pca.distance_line(X1_0, a1_0), pca.distance_line(X1, a1), c='w', edgecolors='k')
plt.show()

# %%
plt.figure(figsize=(W,H))
plt.scatter(X0[:,0], X0[:,1], c='w', edgecolors='k')
plt.scatter([c0[0]], [c0[1]], s=81, c='w', edgecolors='k')
plt.scatter([c[0]], [c[1]], s=81, c='grey', edgecolors='k')
plt.plot([c0[0], c0[0]+8*a1_0[0]], [c0[1], c0[1]+8*a1_0[1]], c='k', linestyle='--', label='pca')
plt.plot([c[0], c[0]+8*a1[0]], [c[1], c[1]+8*a1[1]], c='k', label='robust_pca')
plt.legend()
plt.show()

# %%
plt.plot(sorted(
    array_modified_zscore(pca.distance_line(X1_0, a1_0))), 
    marker='o', markersize=5, label='pca')
plt.plot(sorted(
    array_modified_zscore(pca.distance_line(X1, a1))), 
    marker='s', markersize=5, label='robust_pca')
plt.legend()
plt.minorticks_on()
plt.show()

# %%
plt.plot(sorted(
    pca.distance_line(X1_0, a1_0)), 
    marker='o', markersize=5, label='pca')
plt.plot(sorted(
    pca.distance_line(X1, a1)), 
    marker='s', markersize=5, label='robust_pca')
plt.legend()
plt.minorticks_on()
plt.show()

# %%
plt.scatter(pca.distance_line(X1_0, a1_0), pca.distance_line(X1, a1))
plt.minorticks_on()
plt.grid(1)
plt.show()

# %%
X2 = pca.project(X1, a1)
X2_0 = pca.project(X1_0, a1_0)

# %%
a2_0, L2_0 = pca.find_pc(X2_0, tol=1.0e-9)
print(L2_0, a2_0, a2_0 @ a2_0)
# Out:
# 4.373700529476254 [ 0.731 -0.683] 1.0000000000000002

# %%
# alpha = (N-5)/N
wma = af.averaging_function("WM", rhofunc=funcs.Quantile_Sqrt(alpha, 0.001))
a2, L2 = pca.find_robust_pc(X2, wma, tol=1.0e-9)
print(L2, a2)
print(a1 @ a2)
# Out:
# 2.4694108708836047 [-0.821  0.571]
# 2.7755575615628914e-16

# %%
plt.plot(sorted(pca.distance_line(X2_0, a2_0)), marker='s', markersize=4, label='pca')
plt.plot(sorted(pca.distance_line(X2, a2)), marker='s', markersize=4, label='robust_pca')
plt.legend()
plt.show()

# %%
aa = 16/9
plt.figure(figsize=(5.3, 5.0))
plt.scatter(X0[:,0], X0[:,1], c='w', edgecolors='k')
plt.scatter([c0[0]], [c0[1]], s=100, c='w', edgecolors='k', linestyle='--')
plt.scatter([c[0]], [c[1]], s=100, c='w', edgecolors='k')
plt.plot([c0[0]-10*a1_0[0], c0[0], c0[0]+10*a1_0[0]], [c0[1]-10*a1_0[1], c0[1], c0[1]+10*a1_0[1]], 
         c='k', linestyle='--', label='PCA')
plt.plot([c0[0]-6*a2_0[0], c0[0], c0[0]+6*a2_0[0]], [c0[1]-6*a2_0[1], c0[1], c0[1]+6*a2_0[1]], 
         c='k', linestyle='--')
plt.plot([c[0]-10*a1[0], c[0], c[0]+10*a1[0]], [c[1]-10*a1[1], c[1], c[1]+10*a1[1]], 
         c='k', label='Robust PCA')
plt.plot([c[0]-6*a2[0], c[0], c[0]+6*a2[0]], [c[1]-6*a2[1], c[1], c[1]+6*a2[1]], 
         c='k')
plt.legend()
plt.xlabel('heelstick')
plt.ylabel('katheter')
plt.tight_layout()
# plt.savefig('fig/robust_pca_kelly_0.eps')
plt.show()

# %%
U1 = X1 @ a1
U2 = X1 @ a2

U1_0 = X1_0 @ a1_0
U2_0 = X1_0 @ a2_0

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Robust PCA')
plt.scatter(U1, U2)
plt.minorticks_on()
plt.subplot(1,2,2)
plt.title('PCA')
plt.scatter(U1_0, -U2_0)
plt.minorticks_on()
# plt.savefig('fig/robust_pca_starsCYG_transformed.eps')
plt.show()

# %%
from mlgrad.array_transform import array_modified_zscore

ZU1 = abs(array_modified_zscore(U1))
ZU2 = abs(array_modified_zscore(U2))

ZU1_0 = abs(array_modified_zscore(U1_0))
ZU2_0 = abs(array_modified_zscore(U2_0))

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Robust PCA')
plt.scatter(ZU1, ZU2)
plt.minorticks_on()
plt.subplot(1,2,2)
plt.title('PCA')
plt.scatter(ZU1_0, ZU2_0)
plt.minorticks_on()
plt.show()

# %%
D = U1 * U1 + U2 * U2
D_0 = U1_0 * U1_0 + U2_0 * U2_0

print(D_0.sum(), D.sum())

plt.figure(figsize=(6.5,4*aa))
plt.title('Square distances')
plt.plot(sorted(D), label='Robust PCA')
plt.plot(sorted(D_0), label='PCA')
plt.minorticks_on()
plt.legend()
plt.savefig('fig/robust_pca_starsCYG_SD.eps')
plt.show()
# Out:
# 1047.7995 1053.8780000055165
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from mlgrad.pca.location_scatter import robust_scatter_matrix

# %%
wma = af.averaging_function("WM", rhofunc=funcs.Quantile_Sqrt((N-3)/N, 0.001))
S = pca.robust_scatter_matrix(X1, wma)
print(S)
# Out:
# K: 99
# [[ 1.910 -1.507]
#  [-1.507  1.712]]

# %%
L, A = np.linalg.eig(S)
print(A)
np.dot(A[0], A[1])
# Out:
# [[ 0.730  0.684]
#  [-0.684  0.730]]
# 0.0

# %%
plt.figure(figsize=(5.3,5.0))
plt.scatter(X0[:,0], X0[:,1], c='w', edgecolors='k')
plt.scatter([c0[0]], [c0[1]], s=100, c='w', edgecolors='k', linestyle='--')
plt.scatter([c[0]], [c[1]], s=100, c='w', edgecolors='k')
plt.plot([c0[0]-10*a1_0[0], c0[0], c0[0]+10*a1_0[0]], [c0[1]-10*a1_0[1], c0[1], c0[1]+10*a1_0[1]], 
         c='k', linestyle='--', label='pca')
plt.plot([c0[0]-6*a2_0[0], c0[0], c0[0]+6*a2_0[0]], [c0[1]-6*a2_0[1], c0[1], c0[1]+6*a2_0[1]], 
         c='k', linestyle='--')
plt.plot([c[0]-10*a1[0], c[0], c[0]+10*a1[0]], [c[1]-10*a1[1], c[1], c[1]+10*a1[1]], 
         c='k', label='robust pca i')
plt.plot([c[0]-6*a2[0], c[0], c[0]+6*a2[0]], [c[1]-6*a2[1], c[1], c[1]+6*a2[1]], 
         c='k')
plt.plot([c[0]-10*A[0,0], c[0], c[0]+10*A[0,0]], [c[1]-10*A[0,1], c[1], c[1]+10*A[0,1]], 
         c='k', linestyle='-.', label='robust pca ii')
plt.plot([c[0]-6*A[1,0], c[0], c[0]+6*A[1,0]], [c[1]-6*A[1,1], c[1], c[1]+6*A[1,1]], 
         c='k', linestyle='-.')

plt.legend()
plt.tight_layout()
plt.savefig('fig/robust_pca_kelly_1.eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from sklearn.decomposition import PCA

# %%
pca_sk = PCA()
pca_sk.fit(X1)
AA = pca_sk.components_
print(AA)
pca_sk.mean_
# Out:
# [[ 0.683  0.731]
#  [ 0.731 -0.683]]
# array([0.430, 0.345])

# %%
plt.figure(figsize=(5.3,5))
plt.scatter(X1[:,0], X1[:,1], c='w', edgecolors='k')
plt.scatter([0], [0], s=81, c='b')
plt.plot([-10*AA[0,0], 0, 10*AA[0,0]], [-10*AA[1,0], 0, 10*AA[1,0]], linestyle='--', label='1 (sk)')
plt.plot([-6*AA[0,1], 0, 6*AA[0,1]], [-6*AA[1,1], 0, 6*AA[1,1]], linestyle='--', label='2 (sk)')
plt.plot([-10*A[0,0], 0, 10*A[0,0]], [-10*A[1,0], 0, 10*A[1,0]], label='1')
plt.plot([-6*A[0,1], 0, 6*A[0,1]], [-6*A[1,1], 0, 6*A[1,1]], label='2')
plt.legend()
plt.show()
