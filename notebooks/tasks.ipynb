# %% [markdown]
# # Python

# %% [markdown]
# ### Задача 1
#
# Вычислить сумму квадратов от 1 до 100.

# %% [markdown]
# ### Задача 2
#
# Написать функцию, для вычислить суммы квадратов от 1 до N (N - аргумент функции).

# %% [markdown]
# ### Задача 3
#
# Написать функцию, для вычислить N-го члена последовательности Фибоначи (N - аргумент функции):
#
# $x_1=1$, $x_2=1$
#
# При $n>2$:
# $$
# x_{n+1} = x_n + x_{n-1}
# $$

# %% [markdown]
# ### Задача 4
#
# Построить график функции $y=x\sin(1/(1+|x|))$ на отрезке $[-6, 6]$.

# %% [markdown]
# ### Задача 5
#
# Изобразите на плоскости функцию $z=x^2-y^2$ на квадрате $[-3,3]\times[-3,3]$, с использованием imshow и contour.

# %% [markdown]
# ### Задача 6
#
# Методом наименьших квадратов для набора данных `mammals` построить линейную регрессию для представления заивисимости массы мозга от масся тела животных. Исследовать на наличие выбросов. При наличии выбросов, исключить их и построить линейную регрессии по данным без выбросов. Сравнить распределения ошибок для построенных линейных регрессионных зависимостей.

# %% [markdown]
# ### Задача 7
#
# Идентифицировать выбросы и восстановить линейную регрессиию по набору данных `phones.csv`

# %% [markdown]
# ### Задача 8
#
# Решить 2 задачи классификации на 2 класса, используя инструментаррий из паакета `mltools` и набор данных `iris`:
# * Для набора, содержащего цветки класса 0 и 1;
# * Для набора, содержащего цветки класса 0 и 2.
#
# Определить относительно число правильных ответов.
# Если есть ошибки, то избразить из на проекциях (по парам признаков).

# %% [markdown]
# ### Задача 9
#
# Используя набор данных из robust_wine_2_class.ipynb решить задачу линейной классификации, идентифицировать выбросы, использовать робастный алгоритм классификации, визуализировать результаты.
